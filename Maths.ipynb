# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 10, 100)
#k = np.linspace(0, 10, 100)
k = 1
kn = 3
plt.plot(x, np.cos(k*x))
plt.plot(x, np.cos(kn*x))
